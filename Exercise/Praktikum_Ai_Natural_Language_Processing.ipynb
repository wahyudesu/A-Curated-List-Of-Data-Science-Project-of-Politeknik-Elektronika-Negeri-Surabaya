# %% [markdown]
# <h1><center>Praktikum Kecerdasan Buatan: NLP</center></h1>
# <h2><center>Dosen Pengampu Entin Martiana Kusumaningtyas S. Kom, M. Kom </center></h2>

# %% [markdown]
# <img src="logo pens.png"
#         alt="Picture"
#         width="380"
#         height="380"
#         style="display: block; margin: 0 auto" />

# %% [markdown]
# <h4><center>Wahyu Ikbal Maulana</center></h4>
#
# <h4><center>3323600056</center></h4>
#
# <h4><center>D4 SDT B</center></h4>
#
# <h2><center>Politeknik Elektronika Negeri Surabaya</center></h2>
#   ‎

# %% [markdown]
# ### Tugas Praktikum 1

# %%
import requests
from bs4 import BeautifulSoup
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# Mengambil berita dari kompas.com
url = "https://nasional.kompas.com/read/2024/03/27/05255631/gerindra-prabowo-dan-megawati-bertemu-dalam-waktu-dekat"
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

# %% [markdown]
# <div style="border-radius: 10px; border: #0ea5e9 solid; padding: 15px; background-color: #ffffff00; font-size: 100%; text-align: left;">
#     <b>🖊️ Analisis :</b> Pertama adalah proses web scraping pada sebuah halaman berita dari kompas.com. Proses ini melibatkan pengambilan data HTML dari URL yang ditentukan, dan kemudian parsing data tersebut menjadi struktur yang lebih mudah diolah menggunakan BeautifulSoup. Modul lain seperti requests, nltk.tokenize, dan nltk.corpus digunakan untuk mendukung proses ini.
# </div>

# %%
# Tambahan
from urllib.request import urlopen
from bs4 import BeautifulSoup

html = urlopen(url).read()
soup = BeautifulSoup(html, features="html.parser")

# kill all script and style elements
for script in soup(["script", "style"]):
    script.extract()    # rip it out

# get text
text = soup.get_text()

# break into lines and remove leading and trailing space on each
lines = (line.strip() for line in text.splitlines())
# break multi-headlines into a line each
chunks = (phrase.strip() for line in lines for phrase in line.split("  "))
# drop blank lines
text = '\n'.join(chunk for chunk in chunks if chunk)

print(text)
# Out:
# Gerindra: Prabowo dan Megawati Bertemu dalam Waktu Dekat
# Otomatis
# Mode Gelap
# Mode Terang
# Koin
# Login
# Gabung Kompas.com+
# Konten yang disimpan
# Konten yang disukai
# Atur Minat
# Berikan Masukanmu
# Langganan Kompas.id
# News
# Nasional
# Megapolitan
# Global
# Surat Pembaca
# Kilas Daerah
# Kilas Korporasi
# Kilas
# Kementerian
# Sorot Politik
# Kilas Badan
# Negara
# Kelana
# Indonesia
# Kalbe Health Corner
# Kilas Parlemen
# Kilas BUMN
# Cek Fakta
# Konsultasi Hukum
# Indeks
# Regional
# Surabaya
# Medan
# Makassar
# Yogyakarta
# Bandung
# Denpasar
# Hype
# Ramadhan
# Pemilu
# IKN
# News
# City
# Infrastructure
# Community
# Housings
# Indeks
# Foresta
# Tekno
# Apps & OS
# Gadget
# Internet
# Hardware
# Business
# Game
# Galeri
# Indeks
# Tech Innovation
# Kilas Internet
# Otomotif
# Motor
# Mobil
# Sport
# Niaga
# Komunitas
# Otopedia
# Pameran
# Elektrifikasi
# Bola
# Timnas Indonesia
# Liga Indonesia
# Liga Italia
# Liga Champions
# Liga Lain
# Liga Inggris
# ...

# %%
# Fetch the content of the URL.
response = requests.get(url)
response.raise_for_status()

# Parse the HTML content using BeautifulSoup.
soup = BeautifulSoup(response.content, 'html.parser')

# Find all paragraph elements in the article.
paragraphs = soup.find_all('p')
paragraphs
# Out:
# [<p class="social--dshare" id="dsharetitle">Gerindra: Prabowo dan Megawati Bertemu dalam Waktu Dekat</p>,
#  <p>Tim Redaksi</p>,
#  <p><strong>JAKARTA, KOMPAS.com</strong> - Sekretaris Jenderal (Sekjen) Partai <a class="inner-link-tag" href="https://www.kompas.com/tag/gerindra" style="color:#428bca;" target="_self">Gerindra</a> Ahmad Muzani mengatakan, capres pemenang Pemilu 2024 Prabowo Subianto akan bertemu dengan Ketua Umum <a class="inner-link-tag" href="https://www.kompas.com/tag/pdi-p" style="color:#428bca;" target="_self">PDI-P</a> sekaligus Presiden ke-5 Megawati Soekarnoputri dalam waktu dekat.</p>,
#  <p>Muzani membeberkan, baik kader Gerindra maupun PDI-P sama-sama menginginkan kedua ketum tersebut bertemu.</p>,
#  <p>"Saya yakin, dalam waktu pendek ini kedua beliau bisa bertemu karena semua pihak juga mengharapkan ketuanya bisa bertemu," ujar Muzani saat ditemui di Jakarta Selatan, Selasa (26/3/2024) malam.</p>,
# ...

# %% [markdown]
# <div style="border-radius: 10px; border: #0ea5e9 solid; padding: 15px; background-color: #ffffff00; font-size: 100%; text-align: left;">
#     <b>🖊️ Analisis :</b> Disini saya mengambil mengurai isi dari sebuah URL, lalu melakukan pemisahan menjadi beberapa paragraf
# </div>

# %%
# Mengambil teks berita
text = soup.get_text()
text
# Out:
# '\n\n\n\n\n\n\nGerindra: Prabowo dan Megawati Bertemu dalam Waktu Dekat\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nOtomatis\n\n\nMode Gelap\n\n\nMode Terang\n\n\n\n\n\n\n\n\nKoin\n\n\n\n\n\n\n\n\n\n\n\n\n Login\n\n Gabung Kompas.com+ \n\n Konten yang disimpan\n\n Konten yang disukai\n\n Atur Minat\n\n Berikan Masukanmu \n\n\n\n\n\n\nLangganan Kompas.id\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nNews\n\n\nNasional\n\n\nMegapolitan\n\n\nGlobal\n\n\nSurat Pembaca\n\n\nKilas Daerah\n\n\nKilas Korporasi\n\n\nKilas\n                    Kementerian\n\n\nSorot Politik\n\n\nKilas Badan\n                    Negara\n\n\nKelana\n                    Indonesia\n\n\nKalbe Health Corner\n\n\nKilas Parlemen\n\n\nKilas BUMN\n\n\nCek Fakta\n\n\nKonsultasi Huk
# ...

# %%
import nltk
nltk.download('punkt')

tokens = word_tokenize(text)
tokens
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ['Gerindra',
#  ':',
#  'Prabowo',
#  'dan',
#  'Megawati',
#  'Bertemu',
#  'dalam',
#  'Waktu',
#  'Dekat',
#  'Otomatis',
#  'Mode',
#  'Gelap',
#  'Mode',
#  'Terang',
#  'Koin',
#  'Login',
#  'Gabung',
#  'Kompas.com+',
#  'Konten',
#  'yang',
#  'disimpan',
#  'Konten',
#  'yang',
#  'disukai',
#  'Atur',
#  'Minat',
#  'Berikan',
#  'Masukanmu',
#  'Langganan',
#  'Kompas.id',
#  'News',
#  'Nasional',
#  'Megapolitan',
#  'Global',
#  'Surat',
#  'Pembaca',
#  'Kilas',
#  'Daerah',
#  'Kilas',
#  'Korporasi',
#  'Kilas',
#  'Kementerian',
#  'Sorot',
#  'Politik',
#  'Kilas',
#  'Badan',
#  'Negara',
#  'Kelana',
#  'Indonesia',
#  'Kalbe',
#  'Health',
#  'Corner',
#  'Kilas',
#  'Parlemen',
#  'Kilas',
#  'BUMN',
#  'Cek',
#  'Fakta',
#  'Konsultasi',
#  'Hukum',
#  'Indeks',
#  'Regional',
#  'Surabaya',
#  'Medan',
#  'Makassar',
#  'Yogyakarta',
# ...

# %% [markdown]
# <div style="border-radius: 10px; border: #0ea5e9 solid; padding: 15px; background-color: #ffffff00; font-size: 100%; text-align: left;">
#     <b>🖊️ Analisis :</b> Setelah mengambil isi teks, yang dilakukan selajutnya adalah mendownload modul nltk punkt, lalu melakukan tokenize kalimat kalimat tersebut menjadi teks.
# </div>

# %%
nltk.download('stopwords')

from nltk import word_tokenize

stop_words = set(stopwords.words('indonesian'))
i_filtered_list = [word for word in word_tokenize(text) if not word in stop_words]
i_filtered_list
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ['Gerindra',
#  ':',
#  'Prabowo',
#  'Megawati',
#  'Bertemu',
#  'Waktu',
#  'Dekat',
#  'Otomatis',
#  'Mode',
#  'Gelap',
#  'Mode',
#  'Terang',
#  'Koin',
#  'Login',
#  'Gabung',
#  'Kompas.com+',
#  'Konten',
#  'disimpan',
#  'Konten',
#  'disukai',
#  'Atur',
#  'Minat',
#  'Berikan',
#  'Masukanmu',
#  'Langganan',
#  'Kompas.id',
#  'News',
#  'Nasional',
#  'Megapolitan',
#  'Global',
#  'Surat',
#  'Pembaca',
#  'Kilas',
#  'Daerah',
#  'Kilas',
#  'Korporasi',
#  'Kilas',
#  'Kementerian',
#  'Sorot',
#  'Politik',
#  'Kilas',
#  'Badan',
#  'Negara',
#  'Kelana',
#  'Indonesia',
#  'Kalbe',
#  'Health',
#  'Corner',
#  'Kilas',
#  'Parlemen',
#  'Kilas',
#  'BUMN',
#  'Cek',
#  'Fakta',
#  'Konsultasi',
#  'Hukum',
#  'Indeks',
#  'Regional',
#  'Surabaya',
#  'Medan',
#  'Makassar',
#  'Yogyakarta',
#  'Bandung',
#  'Denpasar',
#  'Hype',
# ...

# %%
# !pip install Sastrawi
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

factory = StemmerFactory()
stemmer = factory.create_stemmer()

stemmed_words = [stemmer.stem(word) for word in i_filtered_list]
stemmed_words
# Out:
# ...
# ['gerindra',
#  '',
#  'prabowo',
#  'megawati',
#  'temu',
#  'waktu',
#  'dekat',
#  'otomatis',
#  'mode',
#  'gelap',
#  'mode',
#  'terang',
#  'koin',
#  'login',
#  'gabung',
#  'kompas com',
#  'konten',
#  'simpan',
#  'konten',
#  'suka',
#  'atur',
#  'minat',
#  'ikan',
#  'masuk',
#  'langgan',
#  'kompas id',
#  'news',
#  'nasional',
#  'megapolitan',
#  'global',
#  'surat',
#  'baca',
#  'kilas',
#  'daerah',
#  'kilas',
#  'korporasi',
#  'kilas',
#  'menteri',
#  'sorot',
#  'politik',
#  'kilas',
#  'badan',
#  'negara',
#  'kelana',
#  'indonesia',
#  'kalbe',
#  'health',
#  'corner',
#  'kilas',
#  'parlemen',
#  'kilas',
#  'bumn',
#  'cek',
#  'fakta',
#  'konsultasi',
#  'hukum',
#  'indeks',
#  'regional',
#  'surabaya',
#  'medan',
#  'makassar',
#  'yogyakarta',
#  'bandung',
#  'denpasar',
#  'hype',
#  'ramadhan',
#  'milu',
#  'ikn',
#  'news',
#  'city',
#  'infrastructure',
#  'community',
#  'housings',
#  'indeks',
#  'foresta',
#  'tekno',
# ...

# %% [markdown]
# <div style="border-radius: 10px; border: #0ea5e9 solid; padding: 15px; background-color: #ffffff00; font-size: 100%; text-align: left;">
#     <b>🖊️ Analisis :</b> Disini kita perlu menginstall dan menggunakan pustaka Sastrawi. Pustaka Sastrawi digunakan untuk NLP dalam bahasa Indonesia, lalu menerapkan operasi stemming.
# </div>

# %%
# Menghitung distribusi frekuensi
from collections import Counter
frequency_distribution = Counter(stemmed_words)

print(frequency_distribution)
# Out:
# Counter({'': 185, 'prabowo': 32, 'nasional': 30, 'megawati': 27, 'temu': 24, 'gerindra': 23, 'pdi-p': 18, '27 03 2024': 16, 'wib': 16, 'kilas': 15, 'baca': 14, 'hak': 13, 'angket': 13, 'sebut': 13, 'jokowi': 13, 'kompas com': 12, '-': 11, 'milu': 10, 'news': 9, 'prabowo-gibran': 9, 'susun': 9, 'kabinet': 9, 'indeks': 8, 'berita': 8, 'muzani': 8, 'pilpres': 8, 'tak': 8, 'hubung': 8, 'tts': 8, 'ketua': 7, 'tunggu': 7, 'hasil': 7, 'mk': 7, 'putus': 7, 'gabung': 6, 'liga': 6, 'umkm': 6, 'lihat': 6, 'ganjar': 6, '2024': 6, 'bukan': 6, 'pilih': 6, 'ini': 6, 'baik': 6, 'kali': 6, 'waktu': 5, 'dekat': 5, 'indonesia': 5, 'ramadhan': 5, 'timnas': 5, 'food': 5, 'iklan': 5, 'soal': 5, 'sengketa': 5, 'pak': 5, 'mungkin': 5, 'kalah': 5, 'peran': 5, 'artikel': 5, 'masuk': 4, 'menteri': 4, 'galeri': 4, 'program': 4, 'didik': 4, 'travel': 4, 'perintah': 4, 'libat': 4, 'lapor': 4, 'sidang': 4, 'sekjen': 4, 'partai': 4, 'tkn': 4, 'langsung': 4, 'lengkap': 4, 'politikus': 4, 'bakal': 4, 'adi': 4, 'itu':
# ...

# %% [markdown]
# <div style="border-radius: 10px; border: #0ea5e9 solid; padding: 15px; background-color: #ffffff00; font-size: 100%; text-align: left;">
#     <b>🖊️ Analisis :</b> Disini saya melakukan analisa jumlah distribusi untuk kata kata yang sering muncul, didapat bahwa huruf spasi, nama subjek memiliki frequensi distribusi yang cukup tinggi.
# </div>

# %% [markdown]
# ### Tugas Praktikum 2

# %%
import nltk
from nltk import CFG
from nltk.parse import RecursiveDescentParser

# Definisi CFG
kalimat = CFG.fromstring("""
    Kalimat -> Subyek Predikat
    Kalimat -> Subyek Predikat Keterangan
    Subyek -> Determinan KataBenda
    Predikat -> KataKerja KataBenda
    Determinan -> 'seorang' | 'seekor'
    KataBenda -> 'manusia' | 'anjing' | 'nasi' | 'daging' | 'air'
    KataKerja -> 'makan' | 'minum'
    Keterangan -> 'kemaren' | 'tadi' """)
rd_parser = RecursiveDescentParser(kalimat)

sentences = [
    "seekor anjing makan daging tadi",
    "seorang manusia minum air kemaren"
]

# Parsing dan menampilkan tree
for sentence in sentences:
    print("Kalimat:", sentence)
    tokens = nltk.word_tokenize(sentence)
    for tree in rd_parser.parse(tokens):
        tree.pretty_print()
# Out:
# Kalimat: seekor anjing makan daging tadi
#                              Kalimat
#               __________________|____________________________
#            Subyek                     Predikat               |
#      ________|________           ________|_________          |
# Determinan        KataBenda KataKerja          KataBenda Keterangan
#     |                 |         |                  |         |
#   seekor            anjing    makan              daging     tadi
#
# Kalimat: seorang manusia minum air kemaren
#                              Kalimat
#               __________________|____________________________
#            Subyek                     Predikat               |
#      ________|________           ________|_________          |
# Determinan        KataBenda KataKerja          KataBenda Keterangan
#     |                 |         |                  |         |
#  seorang           manusia    minum               air     kemaren

# %% [markdown]
# <div style="border-radius: 10px; border: #0ea5e9 solid; padding: 15px; background-color: #ffffff00; font-size: 100%; text-align: left;">
#     <b>🖊️ Analisis :</b> Sebuah CFG didefisinisakn dengan aturan-atura nproduksi yang menggambarkan sutruktur kalimat yang valid dalam bahasa Indonesia. CFG ini terdiri dari produksi-produski yang mendefinisian hubunan natara subyek, predikat,determinan, kata benda, kata kejra, dan keterangan. Parser rekursif turun diinisialisasi dengn CFG yang telah didefinisikan. Kalimat yang ingin dianalisis kemudian disediakna dalam bentuk list. Setiap kalimat diproses oleh parser, lalu struktru parse  tree ditampilkan oleh output.
# </div>
