# %% [markdown]
# <h1><center>Praktikum Pemodelan Statistika Terapan</center></h1>
# <h2><center>Dosen Pengampu Ronny Sutsetyoko</center></h2>

# %% [markdown]
# <img src="logo pens.png"
#         alt="Picture"
#         width="380"
#         height="380"
#         style="display: block; margin: 0 auto" />

# %% [markdown]
# <h3><center>Wahyu Ikbal Maulana</center></h3>
#
# <h3><center>3323600056</center></h3>
#
# <h3><center>D3 SDT B</center></h3>
#
# <h1><center>Politeknik Elektronika Negeri Surabaya</center></h1>
#   ‎

# %% [markdown]
# ## <b><span style='color:#FA5E3C'>|</span> Percobaan 1</b>

# %% [markdown]
# Ini deskripsi tugas

# %%
from sklearn.datasets import load_digits
# %matplotlib inline
import matplotlib.pyplot as plt
digits = load_digits()

plt.gray() 
for i in range(5):
    plt.matshow(digits.images[i])

# %% [markdown]
# <div style="border-radius: 10px; border: #0ea5e9 solid; padding: 15px; background-color: #ffffff00; font-size: 100%; text-align: left;">
#     <b>🖊️ Analisis :</b>
#     Pertama adalah proses web scraping pada sebuah halaman berita dari kompas.com. Proses ini melibatkan pengambilan data HTML dari URL yang ditentukan, dan kemudian parsing data tersebut menjadi struktur yang lebih mudah diolah menggunakan BeautifulSoup. Modul lain seperti requests, nltk.tokenize, dan nltk.corpus digunakan untuk mendukung proses ini.
# </div>

# %% [markdown]
# ## <b><span style='color:#FA5E3C'>|</span> Percobaan 2</b>

# %% [markdown]
# ## <b><span style='color:#FA5E3C'>|</span> Kesimpulan </b>
# lorem ipsum dolor sit amet, consectetur adipis cillum dolor sit amet
