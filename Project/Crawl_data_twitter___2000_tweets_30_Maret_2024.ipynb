# %% [markdown]
# #

# %% [markdown]
# <h1><center>Praktikum Pemodelan Twitter Crawling</center></h1>
# <h2><center></center></h2>

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# <img src="logo pens.png"
#         alt="Picture"
#         width="380"
#         height="380"
#         style="display: block; margin: 0 auto" />

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# <h4><center>Wahyu Ikbal Maulana</center></h4>
#
# <h4><center>3323600056</center></h4>
#
# <h4><center>D4 SDT B</center></h4>
#
# <h2><center>Politeknik Elektronika Negeri Surabaya</center></h2>

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# #

# %%
#@title Twitter Auth Token

twitter_auth_token = '8684a9a776eccf3ae4422b7cf3bfb5e0d3e9b42a'

# %%
# Import required Python package
# !pip install pandas

# Install Node.js (because tweet-harvest built using Node.js)
# !sudo apt-get update
# !sudo apt-get install -y ca-certificates curl gnupg
# !sudo mkdir -p /etc/apt/keyrings
# !curl -fsSL https://deb.nodesource.com/gpgkey/nodesource-repo.gpg.key | sudo gpg --dearmor -o /etc/apt/keyrings/nodesource.gpg

# !NODE_MAJOR=20 && echo "deb [signed-by=/etc/apt/keyrings/nodesource.gpg] https://deb.nodesource.com/node_$NODE_MAJOR.x nodistro main" | sudo tee /etc/apt/sources.list.d/nodesource.list

# !sudo apt-get update
# !sudo apt-get install nodejs -y

# !node -v
# Out:
# Hit:8 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ca-certificates is already the newest version (20230311ubuntu0.22.04.1).
# curl is already the newest version (7.81.0-1ubuntu1.16).
# gnupg is already the newest version (2.2.27-3ubuntu2.1).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.
# gpg: cannot open '/dev/tty': No such device or address
# curl: (23) Failed writing body
# deb [signed-by=/etc/apt/keyrings/nodesource.gpg] https://deb.nodesource.com/node_20.x nodistro main
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:3 https://deb.nodesource.com/node_20.x nodistro InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:7 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:8 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# nodejs is already the newest version (20.12.2-1nodesource1).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.
# v20.12.2
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.25.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Hit:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:3 https://deb.nodesource.com/node_20.x nodistro InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:5 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:8 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ca-certificates is already the newest version (20230311ubuntu0.22.04.1).
# curl is already the newest version (7.81.0-1ubuntu1.16).
# gnupg is already the newest version (2.2.27-3ubuntu2.1).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.
# gpg: cannot open '/dev/tty': No such device or address
# curl: (23) Failed writing body
# deb [signed-by=/etc/apt/keyrings/nodesource.gpg] https://deb.nodesource.com/node_20.x nodistro main
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:3 https://deb.nodesource.com/node_20.x nodistro InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:5 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:8 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# nodejs is already the newest version (20.12.2-1nodesource1).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.
# v20.12.2

# %%
# Crawl Data

filename = 'prabowo.csv'
search_keyword = 'prabowo lang:id'
limit = 100

# !npx -y tweet-harvest@2.6.0 -o "{filename}" -s "{search_keyword}" --tab "LATEST" -l {limit} --token {twitter_auth_token}
# Out:
# Tweet Harvest [v2.6.0]
#
# Research by Helmi Satria
# Use it for Educational Purposes only!
#
# This script uses Chromium Browser to crawl data from Twitter with your Twitter auth token.
# Please enter your Twitter auth token when prompted.
#
# Note: Keep your access token secret! Don't share it with anyone else.
# Note: This script only runs on your local device.
#
#
# Opening twitter search page...
#
#
# Found existing file ./tweets-data/prabowo.csv, renaming to ./tweets-data/prabowo.old.csv
#
# Filling in keywords: prabowo lang:id
#
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/prabowo.csv
# Total tweets saved: 19
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/prabowo.csv
# Total tweets saved: 38
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: /content/tweets-data/prabowo.csv
# Total tweets saved: 56
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/prabowo.csv
# Total tweets saved: 73
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/prabowo.csv
# Total tweets saved: 93
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/prabowo.csv
# Total tweets saved: 113
#
# --Taking a break, waiting for 10 seconds...
# Got 113 tweets, done scrolling...

# %%
import pandas as pd

# Specify the path to your CSV file
file_path = f"tweets-data/{filename}"

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(file_path, delimiter=",")

# Display the DataFrame
display(df)
# Out:
#      conversation_id_str                      created_at  favorite_count  \
# 0    1785554466877653096  Wed May 01 15:40:00 +0000 2024               0
# 1    1785695644633715089  Wed May 01 15:39:52 +0000 2024               0
# 2    1785651560690884956  Wed May 01 15:39:42 +0000 2024               0
# 3    1785695566019854572  Wed May 01 15:39:34 +0000 2024               0
# 4    1785695383198298381  Wed May 01 15:38:50 +0000 2024               0
# ..                   ...                             ...             ...
# 108  1785585127881654283  Wed May 01 15:06:22 +0000 2024               0
# 109  1784744191127367754  Wed May 01 15:06:16 +0000 2024               0
# 110  1784744191127367754  Wed May 01 15:05:28 +0000 2024               0
# 111  1785678044038049809  Wed May 01 15:04:36 +0000 2024               0
# 112  1784525877789028424  Wed May 01 15:04:34 +0000 2024               0
#
#                                              full_text               id_str  \
# 0    @kompascom Partai yg membesarkan n kasi fasili...  1785695675994480806
# 1    Kemarin mimpi prabowo sama jokowi datang kerum...  1785695644633715089
# 2    @yaniarsim @prabowo @gibran_tweet Sy benci ke ...  1785695599733739841
# 3    Jerry Massie: Jokowi dan SBY Jadi Mentor Andal...  1785695566019854572
# 4    @PDI_Perjuangan https://t.co/IalSy804wX . . . ...  1785695383198298381
# ..                                                 ...                  ...
# 108  @Araghutama Kalo kamu mah pasti dibales terus ...  1785687213789130811
# 109  @H1m4_W4r1 @BuayaUbanan @snjayajonggrang @_sek...  1785687188937879838
# 110  @H1m4_W4r1 @BuayaUbanan @snjayajonggrang @_sek...  1785686986944401456
# 111  @BadmintonTalk @BonCabe Gregoria Mariska Tunju...  1785686767292784718
# 112  @sholxs @CAMERALIVE6849 Kenapa Allah pilih Jok...  1785686760259014751
#
#     image_url in_reply_to_screen_name lang                        location  \
# 0         NaN               kompascom   in                        Surabaya
# 1         NaN                     NaN   in                           Medan
# 2         NaN               yaniarsim   in                             NaN
# 3         NaN                     NaN   in                         Jakarta
# 4         NaN          PDI_Perjuangan   in               Rotterdam Holland
# ..        ...                     ...  ...                             ...
# 108       NaN              Araghutama   in  Пряжинский район, Карелия респ
# 109       NaN         Dargomb33306384   in                             NaN
# 110       NaN               H1m4_W4r1   in                             NaN
# 111       NaN           BadmintonTalk   in                             NaN
# 112       NaN                  sholxs   in                             NaN
#
#      quote_count  reply_count  retweet_count  \
# 0              0            0              0
# 1              0            0              0
# 2              0            0              0
# 3              0            0              0
# 4              0            0              0
# ..           ...          ...            ...
# 108            0            1              0
# 109            0            0              0
# 110            0            1              0
# 111            0            0              0
# 112            0            0              0
#
#                                              tweet_url          user_id_str  \
# 0    https://twitter.com/DaddyAshari/status/1785695...            798563634
# 1    https://twitter.com/erzanfadilnst/status/17856...            461901091
# 2    https://twitter.com/KumissabarSaba6/status/178...  1582863767851110400
# 3    https://twitter.com/Kilas_berita_/status/17856...           2544978158
# 4    https://twitter.com/BoyMantouw/status/17856953...           2785383083
# ..                                                 ...                  ...
# 108  https://twitter.com/kelixmann/status/178568721...  1425377301953277953
# 109  https://twitter.com/Dargomb33306384/status/178...  1077474025662668800
# 110  https://twitter.com/Dargomb33306384/status/178...  1077474025662668800
# 111  https://twitter.com/mfirman_firdaus/status/178...            768661484
# 112  https://twitter.com/Heryadi12Herry/status/1785...  1530744078727782401
#
#             username
# 0        DaddyAshari
# 1      erzanfadilnst
# 2    KumissabarSaba6
# 3      Kilas_berita_
# 4         BoyMantouw
# ..               ...
# 108        kelixmann
# 109  Dargomb33306384
# 110  Dargomb33306384
# 111  mfirman_firdaus
# 112   Heryadi12Herry
#
# [113 rows x 15 columns]

# %%
# Cek jumlah data yang didapatkan

num_tweets = len(df)
print(f"Jumlah tweet dalam dataframe adalah {num_tweets}.")
# Out:
# Jumlah tweet dalam dataframe adalah 113.
